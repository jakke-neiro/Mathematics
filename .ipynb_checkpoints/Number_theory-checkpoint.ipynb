# %% [markdown]
# \section{Matematisk bevisföring}
# \subsection{Direkt bevis}
# $p \to q$, $p \to A \to B \to q$
#
# \subsection{Kontrapositionsbevis}
# $p \to q$, $\neg p \to \neg q$
#
# \subsection{Indirekt bevis}
# $q$, antagande $\neg q \to$ motsägelse
#
# Bevisa att $\sqrt{2}$ är irrationellt
#
# $\sqrt{2} = p/q$, $2 = p^2/q^2$, $2q^2 = p^2$, $q^2 = p^2/2$.
#
# $q^2$ är heltal och $p^2$ är heltal, alltså måste 2 ingo i $p$, $p=2r$
#
# $q^2 = (2r)^2/2$, $r^2 = q^2/2$ $q^2$ är heltal ich $r^2$ är heltal, 2 faktor i $q$
#
# $sgf(p, q) = 1 \neq 2$! $\to$ motsägelse!
#
# \subsection{Induktion}
# $1 + 2\sum_{k=0}^n 3^k = 3^{n+1}$
#
# $1 + 2(3^0 + 3^1 + \dots + 3^n) = 3^{n+1}$
#
# Grundsteg, låt $n=0$
#
# $1 + 2\cdot3^0 = 3 = 3^{0+1} = 3$
#
# Induktionsantagande, anta att $n=k$
#
# $1+2\cdot(3^0 + 3^1 + \dots + 3^k) = 3^{k+1}$
#
# Induktionspåstående, sätt att $n=k+1$
#
# $1 + 2(3^0 + 3^1 + \dots + 3^{k+1}) = 3^{k+2}$ (påstående)
#
# $1 + 2(3^0 + 3^1 + \dots +3^k) + 2\cdot3^{k+1} = 3^{k+1} + 2\cdot 3^{k+1} = 3^{k+1}(1+2) = 3^{k+1}\cdot3 = 3^{k+2}$
#
# Alltså gäller påståendet enligt induktionsaxiomet
#
# \section{Logik}
# Negation $\neg$, disjunktion $\lor$, konjunktion $\land$, implikation $\to$, ekvivalens $\iff$
#
# Sanningsvärden
#
# Tautologi: alltid sant
#
# Logisk ekvivalens: samma sanningsvärde
#
# \subsection{Predikatlogik}
# Existenskvantorn $\exists$, allkvantorn $\forall$
#
# $\exists x \forall y: p(x, y)$: ett $x$ så att för varje $y$ gäller
#
# $\forall x \exists y: p(x, y)$ för varje $x$ finns ett $y$, så att satsen gäller
#
# \section{Talteorins grunder}
#
# \section{Perusasioita joukoista, Mängdlära, Set theory}
# \subsection{Merkintöjä}
# $A = \{-2,-1, 0, 1, 2\}$ alkiot, element
#
# $\N = \{0,1,2, \dots\}$, $Z = \{\dots, -2,-1,0,1,2, \dots \}$, $\Q = \{m/n: m, n \in \Z, n \neq 0 \}$, $\R$
#
# $B = \{m \in \Z | m=2n, n \in \Z\}$
#
# \subsection{Yhdiste, leikkaus ja erotus}
# Yhdiste: $A \cup B = \{x | x \in A \lor x \in B$
#
# Leikkaus: $A \cap B = \{x| x \in A \land x \in B \}$
#
# Erotus: $A \setminus B = \{x | x \in A \land x \notin B\}$
#
# \subsection{Tyhjä joukko}
#
# \subsection{Osajoukko}
# Joukko $A$ on joukon $B$ osajoukko, jos $\forall x \in A$ pätee myös $x \in B$. $A \subset B$
#
# \begin{example}
# $X = \{2,3,\{1\}, \{4,2\}\}$, $A = \{2,3\}$, $B = \{1\}$, $C = \{\{1\}, 3\}$, $A \subset X$, $B \not\subset X$, $C \subset X$
# \end{example}
#
# $]a,b[ = \{x \in \R | a < x < b\}$
#
# $[a, b[ = \{x \in \R | a \leq x < b\}$
#
# $[a,b] = \{x \in \R|a \leq x \leq b\}$
#
# $]a,b] = \{x \in \R|a < x \leq b \}$
#
# \subsection{Osajoukoksi osoittaminen}
# $(A \cup B)\setminus B \subset A?$
#
# $a \in (A \cup B) \setminu B \to a \in A \cup B, a \notin B \to a \in A ´\lor a \in B \to a \in A$
#
# \subsection{Joukkojen osoittaminen samaksi}
# $A$ ja $B$ ovat samat, jos niissä on täsmälleen samat alkiot eli kaikilla alkioilla $x$ pätee seuraava: $x \in A$, jos ja vain jos $x \in B$.
#
# \begin{example}
# $A \cup (B \cap C) = (A \cup B) \cap (A \cup C)$
#
# $x \in A \cup (B \cap C) \to x \in A \lor x \in B \cap C$
#
# 1. $x \in A \to x \in A \cup B, x \in A \cup C \to x \in (A \cup B) \cap (A \cup C)$
#
# 2. $x \in B \cup C \to x \in B, x \in C \to x \in A \cup B, x \in A \cup C \to x \in (A \cup B) \cap (A \cup C)$
# \end{example}
#
# \subsection{Perusjoukko ja komplementti}
# $X$ tarkasteltava perusjoukko. Joukon $A \subset X$ komplementti on joukko $\complement A = \{x \in A|x \notin A \}$
#
# \subsection{Potenssijoukko}
# Kaikkien osajoukkojen muodostama joukko
# \[
# \mathcal{P}(X) = \{A | A \subset X \}
# \]
# \begin{example}
# $X = \{3,1,4 \}$,
#
# $\mathcal{P}(x) = \{\emptyset, \{3\}, \{1\}, \{3\}, \{3, 4\}, \{1, 4\}, X \}$
# \end{example}
#
# \subsection{Joukkojen karteesinen tulo eli tulojoukko}
# $A \tims B = \{(a, b) | a \in A \land b \in B\}$
#
# $C = \{2,3,4\}$, $D = \{1,2\}$
#
# $C \times D = \{(x, y)|x\inX, y \in D\} = \{(2,1), (2,2), (3,1), (3,2), (4,1), (4,2) \}$
#
# \section{Logiikka}
# \subsection{Loogiset konnektiivit}
# Propositiolauseita, totuustaulut
#
# \subsection{Looginen ekvivalenssi}
# Propositiolauseet $A$ ja $B$ ovat loogisesti ekvivalentteja, jos ekvivalenssi $A \iff B$ on tautlogia (totuusarvo aina 1).
#
# \subsection{Kvanttorit}
# $\forall x A$ A pätee kaikilla muuttujan $x$ arvoilla
# $\exists x A$ A pätee joillakin muuttujan $x$ arvoilla
#
# \subsection{Kvanttorit ja negaatiot}
# Joku on iloinen $\exists x I(x)$
#
# Kaikki ovat iloisia $\forall x I(x)$
#
# Kukaan ei ole iloinen $\forall x \neg I(x)$
#
# Joku ei ole iloinen $\exists x \neg I(x)$
#
# Kaikki iloiset ovat ahkeria $\forall x (I(x) \to A(x))$
#
# Joku on iloinen mutta ei ahkera $\exists (I(x) \land \neg A(x))$
#
# \subsection{Kvanttorien järjestys}
# $\forall x \exists y(x+y = 5)$
#
# $\exists yy \forall x (x+y=5)$
#
# $\neg \forall x A \iff \exists c \neg A$
#
# $\neg \exists x A \iff \forall x \neg A$
#
# \section{Todistustekniikka}
# \subsection{Väitteen kumoaminen vastaesimerkillä}
# \begin{example}
# $n^2 - n + 11$ on alkuluku $\forall n \in \Z$
#
# $n^2 - n + 11 = 121 = 11\cdot11$ väite on epätosi!
# \end{example}
#
# \begin{example}
# $A\cup(B\cup C) = (A \cup B)\cap C$
#
# Valitaan $A = \{1,2\}$, $B=\{2,3\}$, $C=\{1,3\}$
#
# $A \cup (B \cup C) = \{1,2,3\}$
#
# $(A \cup B) \cap C = \{1,3\}$
# \end{example}
#
# \subsection{"Jos..., niin" -tyyppisen väiteen todistaminen}
# Oletetaan, että etujäsen $P$ on tosi. Päätellään, että tällöin myös $Q$ pätee.
#
# \begin{example}
# Jos kokonaisluku $m$ on parillinen, niin $m^2$ on parillinen.
#
# $m=2k, k \in \Z$, $m^2 = (2k)^2 = 4k^2$, $2k^2$, joten $m^2$ on parillinen
# \end{example}
#
# \subsection{"Jos ja vain jos" -tyyppisen väitteen todistaminen}
# Oletetaan, että $P$ pätee. Päätellään, että tällöin myös $Q$ pätee. Oletetaan, että $Q$ pätee. Päätellään, että tällöin myös $P$ pätee.
#
# \begin{example}
# Yhtälö $x^2 -6x +9=0$ totetuu, jos ja vain jos $x=3$
#
# $\to$ $x^2 - 6x + 9 = 0 \iff x=3$
#
# $\Leftarrow$ $x=3, 3^2 -6\cdot3 + 9 = 0$
#
# Lemma: Oletetaan, että $A, B$ ja $X$ ovat joukkoja. Tällöin $x \subset A \cap B$, jos ja vain jos $X \subset A$ ja $X \subset B$
# \end{example}
#
# \subsection{Kontrapositiotodistus}
# Oletetaan, että $\neg Q$ on tosi. Päätellään, että tällöin myös $\neg P$ on tosi.
#
# \begin{example}
# $m \in \Z$, Jos $m^2$ on parillinen, niin $m$ on parillinen.
#
# $m^2 = (2k+1)^2 = 2(2k^2 + 2k) +1$
#
# $m^2$ on pariton $\to$ $m$ on pariton
# \end{example}
#
# \subsection{Ristiriitatodistus, epäsuora todistus}
# Tehdään vastaoletus eli oletetaan, että $\neg P$ on tosi. Päätellään ristiriita $C \land \neg C$
#
# \begin{example}
# $a, b \in \Z$, $a^2 - 4b \neq 2$
#
# Oletus: $a^2 - 4b = 2, a^2 = 2 + 4b = 2(1 + 2b) \iff a$ on parillinen $a=2k$
#
# $(2k)^2 - 4b = 2 = 4k^2 - 4b = 2 \iff 2k^2 - 2b = 1, 1 = 2(k^2 - b)$
#
# Luku $1$ on parillinen $\to$ ristiriita.
# \end{example}
#
# \section{Matemaattinen induktio}
# Luonnolliset luvut $\N$ toteuttavat induktioaksiooman
#
# \begin{enumerate}
#     \item Nolla on luonnollinen luku $0 \in \N$
#     \item Jokaista luonnollista lukua $n$ kohti on olemassa täsmäleen yksi luonnollinen luku $s(n)$, jota sanotaan luvun $n$ seuraajaksi.
#     \item Nolla ei ole minkään luonnollisen luvun seuraaja $0 \neq s(n) \forall n \in \N$
#     \item Eri luvuilla on eri seuraajat, $m \neq n \to s(m) \neq s(n)$
#     \item Oletetaan, että $A \subset \N$. Oletetaan lisäksi, että $O \in A$, ja että $\forall n \in \N$ pätee: jos $n \in A$, niin $s(n) \in A$. Tällöin $A = \N$
# \end{enumerate}
#
# \subsection{I Induktioperiaate}
# Oletetaan, että seuraavat ehdot ovat voimassa:
# \begin{example}
#     \item Luvulla $0$ on ominaisuus $P$.
#     \item Kaikilla luonnollisilla luvuilla pätee: jos luvulla $n$ on ominaisuus $P$, niin sitä seuraavalla luvulla $n + 1$ on ominaisuus $P$. Tällöin kaikilla luonnollisilla luvuilla on ominaisuus $P$.
# \end{example}
#
# Todistus: $A = \{n \in \N| P\}$, $A \subset \N$, $0 \in A$, $\forall n \in \N$, $n \in A \to n + 1 \in A$. $n \in A \o s(n) \in A$, $A = \N$
#
# 1. $P(0)$, 2. $\forall n \in \N (P(n) \to P(n+1))$. Tällöin $\forall n \in \N$, $P(n)$
#
# Alkuaskel: $P(0)$, Induktioaskel: Oletetaan, $k \in \N P(k)$, näytetään $P(k+1)$
#
# \begin{example}
# $\sum_{j=0}^n 2j = n(n+1)$,
#
# $j=0 \to 2 \cdot 0 = 0 = 0(0+1)$
#
# $j = k$, $\sum_{j=0}^k 2j = k(k+1)$ Induktio-oletus
#
# $\sum_{j=0}^{k+1}2j = \sum_{j=0}^k 2j + 2(k+1) = k(k+1) + 2(k+1) = (2+k)(k+1)$ Induktioväite
#
# Johtopäätös: Alkuaskeleesta ja induktioaskeleesta seuraa induktioperiaatteen nojalla että $\forall n \in \N$
# \end{example}
#
# Määritelmä: Kokonaisluku $z$ on jaollinen kokonaisluvulla $m$, jos jollakin kokonaisluvulla $a$ pätee $z = am$. Tällöin merkitään $m \mid z$ ja sanotaan, että luku $m$ jakaa luvun $z$.
#
# \subsection{II Induktioperiaate}
# \begin{enumerate}
#     \item Luvulla 0 on ominaisuus $P$
#     \item Jos luvulla $n$ ja kaikilla sitä pienemmillä luonnollisilla luvuilla on ominaisuus $P$, niin luvulla $n+1$ on ominaisuus $P$.
# \end{enumerate}
#
# \begin{enumerate}
#     \item $P(0)$
#     \item $\forall n \in \N$$((\forall j \leq n P(j)) \to P(n+1))$. Tällöin $\forall n \in \N P(n)$
# \end{enumerate}
#
# \begin{example}
# $z_0 = 2$, $z_1 = 1$, $z_n = z_{n-1} + 2z_n -2$, $z_n = 2^n + (-1)^n$
#
# Alkuaskel: $2^0 + (-1)^0 = 1 + 1 = 2 = z_0$
#
# Induktioaskel: $k \in \N, z_j = 2^j + (-1)^j$
#
# Induktioväite: $z_{k+1} = 2^{k+1} + (-1)^k +1$
#
# $z_{k+1} = z_k + 2z_{k-1} = 2^{k+1} + (-1)^{k+1}$
# \end{example}
#
# \section{Perusasioita kuvauksista, avbildningar}
# \subsection{Kuvauksen määritelmä}
# Määritelmä: Oletetaan, että $X$ ja $Y$ ovat joukkoja. Kuvaus joukosta $X$ joukkoon $Y$ on sääntö, joka liittää joukon $X$ jokaiseen alkioon täsmälleen uhden alkion joukosta $Y$.
#
# Funktiot ovat kuvauksia!
#
# \subsection{Kuva, bild}
# Määritelmä: Oletetaan, että $f: X \to Y$ on kuvaus. Oletetaan lisäksi, että $A \subset X$. Joukon $A$ kuva kuvauksessa $f$ on joukko
# \[
# fA = \{y \in Y | y = f(a), a \in A\}
# \]
# \begin{example}
# $f: \R \to \R$, $f(x) = x^2 - 2$, $A = [1,2]$, $fA = [-1,2]$
# \end{example}
#
# \subsection{Alkukuva, urbild}
# Määritelmä: Oletetaan, että $f: X \to Y$ on kuvaus.  Oletetetaan lisäksi, että $B \subset Y$. Joukon $B$ alkukuva kuvauksessa $f$ on joukko
# \[
# f^{\Leftarrow}B = \{x \in X | f(x) \in B \}
# \]
# \begin{example}
# $f: \R \to \R$, $f(x) = x^2 - 2$, $B = [1,2]$
#
# $f^{\Leftarrow}B = [-2, -1] \cup [1,2]$
# \end{example}
#
# \begin{example}
# Olkoon $f:X \to Y$ kuvaus. Osoita $f[f^{\Leftarrow}B] \subset B$, $\forall B \subset Y$
#
# $B \subset Y$, $y \in f[f^{\Leftarrow}B] \to y \in Y$ ja $y = f(x), x \in f^{\Leftarrow}B$
#
# $x \in f^{\Leftarrow}B = \{x \in X | f(x) \in B\}$, $f(x)\in B$, $y(x) = f(x) \to y \in B$
# \end{example}
#
# \subsection{Injektio}
# Määritelmä: Kuvaus $f: X \to Y$ on injektio, jos kaikilla $x_1, x_2 \in X$ yhtälöstä $f(x_1) = f(x_2) \to x_1 = x_2$
#
# \begin{example}
# $g: \R \to \R$, $g(x) = 2 - 0.25x$ injektio?
#
# $x_1, x_2 \in \R$, $g(x_1) = g(x_2)$
#
# $2 - 0.25x_1 = 2 - 0.25 x_2$
#
# $-0.25x_1 = -0.25x_2$
#
# $x_1 = x_2$ \qedsymbol
#
# \begin{example}
#
# \end{example}
# $P: [1, \infty[ \to \R$, $p(x) = x^2 - 2x$
#
# $x_1, x_2 \in [1, \infty[$, $p(x_1) = p(x_2)$
#
# $a, b \in [1, \infty)$
#
# $a^2 - b^2 - 2a + 2b = 0$, $(a+b)(a-b) - 2(a-b) = 0$
#
# $(a-b)(a + b - 2) = 0$, $a = b$, $a = 2 - b \leq 2 -1 = 1a = 1-b$
# \end{example}
#
# \subsection{Surjektio}
# Määritelmä: Kuvaus $f: X \to Y$ on surjektio, jos jokaisella $y \in Y$ on olemassa inakin yksi sellainen $x \in X$, että $f(x) = y$
#
# \begin{example}
# $g: \R \to \R$, $g(x) = 2 - 0.25x \forallx \in \R$
#
# $ y \in \R$, $-4y + 8 \in \R$
#
# $g(-4y + 8) = 2 - 0.25 (-4y + 8) = 2 + y -2 = y$
#
# Jokaista $y\in R$ on olemassa $x=-4y +8 \in \R$, että $g(x) = y$
# \end{example}
#
# Lause: Kuvaus $f: X \to Y$ ja $g: Y \to Z$ ovat kuvauksia. Yhdistetty kuvaus $g \circ f: X \to Y$ määritellään
# \[
# (g \circ f)(x) = g(f(x)) \forall x \in X
# \]
#
# \begin{example}
# $f: \R \to \R$, $f(x) = 2 -x$, $\forall x \in \R$
#
# $g:[0, \infty[ \to \R, g(x) = \sqrt{x} -1, x \geq 0$
#
# $f \circ g: [0, \infty [ \to \R$, $f \circ g(x) = f(g(x)) = f(\sqrt{x} -1) = 2 - (\sqrt{x} -1) = 2\sqrt{x}+1 = 3 - \sqrt{x}$
# \end{example}
#
# \subsection{Käänteiskuvaus ja bijektio}
# Määritelmä: Joukon $X$ identtinen kuvaus tarkoittaa kuvausta $id_{X}: X \to Y$, jolla $id_{X}(x) = x \forall x \in X$
#
# Määritelmä: Oletetaan, että $f:X \to Y$ on kuvaus. Jos on olemassa sellainen kuvaus $g:Y \to X$, että $g \circ f = id_X$, $f \circ g = id_Y$, $f^{-1}=g$
#
# \begin{example}
# $f: \R \to \R$, $f(x) = 2 - x \forall x \in \R$
#
# $g: [0, \infty[ \in \R$
#
# $f \circ g(x) = f(g(x)) = f(\infty{x} - 1) = 2 - (\infty{x} -1) = 2\infty{x}+1 = 3 - \infty{3}$
# \end{example}
#
# \subsection{Käänteiskuvaus ja bijektio}
# Määritelmä: Joukon $X$ identtinen kuvaus tarkoittaa kuvausta $id_{X}: X \to Y$, jolla $id_{X}=X \forall x \in X$.
#
# Määritelmä: Oletetaan $f: X \to Y$ on kuvaus. Jos on olemassa sellainen $g: Y \to X$, että $g \circ f = id_{X}$, $f \circ g = Id_Y$, $f^{-1} = g$
#
# \begin{example}
# $f: \R \to \R$, $f(x) = 4 - 3x$, $g: \R \to \R$, $g(x) = 4/3 - x/3$
#
# $g \circ f(x) = g(f(x)) = g(4-x) = x = id_x$, $f \circ g = f(4/3 - x/3) = id_x$
# \end{example}
#
# Määritelmä: Bijektio on kuvaus, joka on sekä injektio että surjektio. $f: X \to Y$ on kuvaus. Kuvauksella on käänteiskuvaus, jos ja vain jos $f$ on bijektio.
#
# \begin{example}
# Esim. $f: \R \setminus \{1\} \to \R \setminus\{2\}$
#
# $f(x) = 2x/(x-1)$, $x = -y/(2-y)$
#
# $g: \R \setminus \{2\} \to \R\setminus\{1\}$, $g(x) = -x/(2-x)$
# \end{example}
#
# \section{Relaatiot}
# \subsection{Relaation määritelmä}
# Määritelmä: $X$ ja $Y$ ovat joukkoja
#
# $R \subset X \times Y$, $R$ on joukkojen $X$ ja $Y$ välinen relaatio
#
# $R \subset X \times X$, $R$ on joukon $X$ relaatio
#
# $(a,b) \in \R$, alkio $a$ on relaatiossa $R$ alkion $b$ kanssa $aRb$
#
# \begin{example}
# $X=\{1,2,3\}$, $Y = \{n \in \N|1\leqn\leq9\}$
#
# $R = \{(1,1), (1,2), (2,4), (3,6), (3,9)\} \subset X \times Y$ on relaatio
#
# $X = \{1,2,3,4,5\}$, $R = \{(a, b) \in X \times X |a + b < 6 \}$, $(2,3) \in R$
# \end{example}
#
# \subsection{Relaation refleksiivisyys, symmetrisyys ja transitiivisuus}
# $R$ on joukon $X$ relaatio. Relaatio $R$ on
# \begin{enumerate}
#     \item Refleksiivinen: $\forall x \in X$ pätee $xRx$ eli $(x,x) \in \R$
#     \item Symmetrinen: $aRb \to bRa$
#     \item Transitiivinen: $aRb$ ja $bRc$ $\to$ $aRc$
# \end{enumerate}
#
# \begin{example}
# $X = \{1,2,3\}$, $P(x)$ relaatio $S$ seuraavasti $S = \{(a, B) \in P(x) \times P(x)|A \subset B\}$
# \end{example}
#
# \subsection{Ekvivalenssirelaatio ja ekvivalenssiluokat}
# $R$ on joukon $X$ relaatio. Jos $R$ on refleksiivinen, symmetrinen ja transitiivinen, niin $R$ on ekvivalenssirelaatio.
#
# Määritelmä: Oletetaan, että $R$ on joukon $X$ ekvivalenssirelaatio. Alkion $a \in X$ ekvivalenssiluokka on
# \[
# [a]_R = \{x \in X |(x,a) \in \R\} = \{x \in X | xRa \}
# \]
#
# Alkiota $a$ sanotaan ekvivalenssiluokan $[a]_R$ edustajaksi.
#
# Kaikkien ekvivalenssiluokkien muodostamaa joukkoa merkitään $X/R$. Siis $X/R = \{[a]_R | a \in X\}$
#
# \section{Kompleksiluvut}
# \subsection{Kompleksilukujen määritelmä}
# Määritelmä: Kompleksilukujen joukko $\C$ on joukko $\{(a, b)|a, b \in \R\}$, varustettu yhteenlaskulla $(a,b) + (c,d) = (a+c,b+d)$ ja kertolaskulla $(a,b)\cdot(c, d) = (ac-bd, ad + bc)$.
#
# Määritelmä: Oletetaan, että $a, b \in \R$. Kompleksiluvun $z = (a,b)$ reaaliosa on $Rez = a$ ja imaginaariosa on $Imz = b$.
#
# Määritelmä: Oletetaan, että $z \in \C$ ja $z \neq 0$. Jos $Re z = 0$, sanotaan kompleksiluvun $z$ olevan puhtaasti imaginaarinen.
#
# Määritelmä: Kompleksilukua $(0,1)$ kutsutaan imaginaariyksiköksi ja merkitään symbolilla $i$.
#
# Lause: Imaginaariyksikölle $i$ pätee $i^2 = -1$
#
# \subsection{Kompleksilukujen esitys imaginaariyksikön avulla}
# $\C = \{a + bi|a,b \in \R\}$, $z = 6 -9i, z = (6, -9)$
#
# \subsection{Kompleksiluvuilla laskeminen}
# $z + w = (-4-2i) + (3+5i) = -4+3-2i + 5i = -1 + 3i$
#
# $zw = (-4-2i)(3+5i) = -4\cdot3 - 4\cdot5i -2i \cdot 3 -2i \cdot 5i = -12 -20i -6i -10i^2 = -2-26i$
#
# Määritelmä: $a,b \in \R$. Kompleksiluvun $z=(a,b)$ vastaluku on $-z=(-a, -b)$. Kompleksilukujen $z$ ja $w$ erotus tarkoittaa summaa $z+(-w)$. Sitä merkitään $z-w$.
#
# \subsection{Kompleksiluvun liittoluku ja itseisarvo}
# Määritelmä: Oletetaan, että $a,b \in \R$. Kompleksiluvun $z = a + bi$ liittoluku eli kompleksikojugaatti on $\overline{z} = z^* = a - bi$
#
# Lause: $\overline{z + w} = \overline{z} + \overline{w}$, $\overline{zw} = \overline{z}\overline{w}$, $\overline{\overline{z}}=z$, $\Im z = 0 \to \overline{z} = z$
#
# Määritelmä: $a,b \in \R$. Kompleksiluvun $z=a + bi$ itseisarvo on $|z| = \sqrt{a^2 + b^2}$. Itseisarvon toinen nimitys on moduli.
#
# Lause: $|z| = \sqrt{z \overline{z}}$
#
# Lause: $z, w \in \C$. Tulon $zw$ itseisarvo on lukujen $z$ ja $w$ itseisarvojen tulo $|zw|=|z|\cdot|w|$
#
# Lause: Oletetaan, että $z,w \in \C$. Jos $zw=0$, niin $z=0$ tai $w=0$.
#
# \subsection{Kompleksiluvun käänteisluku ja kompleksilukujen osamäärä}
# Määritelmä: Kompleksiluvun $z \neq 0$ käänteisluku on
# \[
# z^{-1} = \frac{1}{|z|^2}\overline{z} = 1/z
# \]
#
# Lause: Kompleksiluvun ja sen käänteisluvun tulo on yksi.
#
# Määritelmä: $z, w \in \C, w \neq 0$. Kompleksilukujen $z$ ja $w$ osamäärä on $z/w = zw^{-1}$.
# \[
# z^{-1} = 1/z = 1/(-4 + 7i) = \frac{-4-7i}{(-4+7i)(-4-7i)} = \frac{4}{65} - \frac{7}{65}i
# \]
#
# Lause: Oletetaan, että $z \in \C$ ja $z \neq 0$. Käänteisluvun $z^{-1}$ itseisarvo on itseisarvon käänteisluku $1/|z|$ eli $|z^{-1}| = 1/|z|$
#
# \subsection{Yhtälön ratkaisemisesta}
# $iz + 3 = 5z - z/i -zi$, $z = \frac{3i + 2}{5i} = 0.6 - 0.4i$
#
# \subsection{Napaesitys}
# Määritelmä: Kompleksiluvun $z$ napaesitys tarkoittaa sen esittämistä muodossa $z = |z|(\cos\phi + i\sin\phi)$
#
# $|z|$ on moduli, $\phi$ on vaihekulma eli argumentti
#
# Lause: Oletetaan, että kompleksiluvulla $z$ on napaesitys $z = |z|(\cos \phi + i \sin \phi)$. Tällöin luvun $z$ liittoluku on
# \[
# \overline{z} = |z|(\cos(-\phi) + i\sin(-\phi))
# \]
# ja kääntesiluku
# \[
# z^{-1} = |z|^{-1}(\cos(-\phi) + i \sin(-\phi))
# \]
#
# Lause: Oletetaan, että luvuilla $z, w \in \C$ on napaesitykset $z = |z|(\cos \phi + i \sin \phi)$ ja $w = |w|(\cos \theta + i\sin(-\phi))$. Tällöin
# \[
# zw = |z||w|(\cos(\phi \theta) + i\sin(\phi + \theta))
# \]
# \[
# z/w = |z|/|w| (\cos(\phi - \theta) + i \sin(\phi - \theta))
# \]
# Määritelmä: $z \in \C$ ja $n \in N$. $z \neq 0$.
# \[
# z^{-n} = (z^n)^{-1}
# \]
# Lause: (de Moivren kaava). Oletetaan, että $z \neq 0$ on napaesitys $z = |z|(\cos \phi + i \sin \phi)$. Tällöin $\forall n \in \Z$
# \[
# z^n = |z|^n (\cosn\phi + i \sin n \phi)
# \]
#
# \subsection{Eksponenttiesitys}
# Määritelmä: $\phi \in \R$. Tällöin $e^{i\phi} = \cos \phi + i \sin\phi$
#
# Määritelmä: Kompleksiluvun $z$ eksponenttiesitys
# \[
# z = |z|e^{i\phi}
# \]
# $\phi$ on luvun $z$ vaihekulma
#
# \subsection{Binomiyhtälö}
# Määritelmä: $w \in \C$, $n \in \N, n \geq 1$. $x^n = w$ on binomiyhtälö.
#
# \begin{example}
# $x^5 = 1$, $1 = e^{0i}$, $x = re^{i\phi}$
#
# $(re^{i\phi)^5 = e^{0i}}$, $r^5e^{5i\phi} = e^{0i}$
#
# $\begin{cases}r^5 = 1 \\ 5\phi - 0 = k 2\pi\end{cases}$, $\begin{cases}r = 1 \\ \phi = k 2/5 \pi \end{cases}$, $\begin{cases}r = 1\\ \phi = k 2/5 \pi
# \end{cases}$
# \end{example}
#
# \subsection{Toisen asteen yhtälö}
# $x^2 = -9$, $(re^{i\phi})^2 = 9e^{\pi i}$, $r^2 e^{2i \phi} = 9e^{\pi i}$
#
# $\begin{cases} r^2 = 9 \\2\phi - \pi = k 2\pi \end{cases}$
#
# $\begin{cases}r = 3 \\ \phi = \pi/2 + k\pi \end{cases}$
#
# Määritelmä: Oletetaan, että $a \in \R$ ja $a \geq 0$. Luvun $a$ neliöjuuri tarkoittaa reaalilukua $b$, jolle pätee: $b^2 = a$, $b \geq 0$
#
# Lause: Oletetaan, että $r \in \R$ ja $r < 0$. Yhtälöllä $x^2 = r$ on kompleksilukujen joukossa tasan kaksi ratkaisua, jotka ovat $i\sqrt{|r|}$ ja $-i\sqrt{|r|}$
#
# Lause: Oletetaan, että $a, b, c \in \R$ ja $ a\neq 0$. Yhtälön $ax^2 + bx + c = 0$ ratkaisut saadaan seuraavasti: Jos diskriminantti $b^2 - 4ac \geq 0$, yhtälön ratkaisut ovat
# \[
# x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a}
# \]
# Jos diskriminantti $b^2 - 4ac < 0$, yhtälön ratkaisut ovat
# \[
# x = \frac{-b \pm i\sqrt{|b^2 - 4ac|}}{2a}
# \]
#
# \section{Tietojenkäsittelytieteen ja tilastotieteen työkaluja}
# \subsection{Binomikertoimet ja kertoma}
# \[
# {n \choose k} = {n-1 \choose k-1} + {n-1 \choose k}
# \]
# Kertoma $n!$, $0!=1$, $(n+1)!=(n+1)n!$
# \[
# {n \choose k} =\frac{n!}{k!(n-k)!}
# \]
# Lause: Oletetaan, että $a, b \in \R$. Tällöin kaikilla $n \in \N, n \geq 1$ pätee
# \[
# (a+b)^n = \sum_{k=0}^n {n \choose k}a^{n-k}b^k
# \]
#
# \subsection{Geometrinen lukujono ja geometrinen sarja}
# Määritelmä: Lukujono $(a_n)$, $n \in \N$ on geometrinen, jos on olemassa sellainen $q \in \R$, $a_{n+1}=qa_n$
#
# Lause: $(a_n)$, $n \in \N$ geometrinen lukujono, suhdeluku $q$. Tällöin
# \[
# a_n = a_0q^n
# \]
# Määritelmä: $\sum_{k=0}^{\infty}aq^k = a + aq + aq^2 + \dots$
#
# Määritelmä: $a_1q \in \R$, $n \in \N \setminus \{0\}$
#
# $\sum_{k=0}^{\infty} aq^k = a + aq + aq^2 + \dots$
#
# $S_n = \sum_{k=0}^{n-1}aq^k $
#
# Lause: $a, q\in \R$, $n \in \N \setminus \{0 \}$
# \begin{enumerate}
#     \item $q=1$ $\to$ $S_n = \sum_{k=0}^{n-1}aq^k = a \frac{1-q^n}{1-q}$
#     \item $q=1$, $S_n = \sum_{k=0}^{n-1}aq^k = na$
# \end{enumerate}
#
# Lause: Geometrinen sarja suppenee, jos ja vain jos $-1 < q < 1$.
# \[
# \sum_{k=0}^{\infty}aq^k = \frac{a}{1-q}
# \]
#
# \subsection{Eksponentti- ja logaritmifunktiot}
# $\log_2(x) = a$, $2^a = x$
#
# $x \in \R_+$ ja $c \in \R$, $\log_2(x^c) = x \log_2(x)$
#
# $x, y > 0$, $\log_2(xy) = \log_2(x) + \log_2(y)$
#
# $x, y > 0$, $\log_2(x/y) = \log_2(x) - \log_2(y)$
#
# \subsection{Jaollisuus ja kongruenssi}
# Määritelmä: Kokonaisluku $z$ on jaollinen kokonaisluvulla $m$, jos jollakin kokonaisluvulla $a$ pätee $z = am$. Tällöin merkitään $m \mid z$
#
# Lause: $a, b \in \Z$, $b \neq 0$, $a = qb + r$, $0 \leq r < |b|$
#
# $r=$jakojäännös, $a \textrm{mod} b = r$
#
# Määritelmä: $a, b \in \Z, n \in \N \setminus \{0\}$
#
# $a \equiv b (\textrm{mod} n)$
#
# Lause: $a, b \in \Z, n \in \N \setminus \{0\}$, $a \equiv b (\textrm{mod} n), n \mid (a-b)$
#
# Lause: $a,b,c,d \in \Z$ ja $k, n \in \N \setminus \{0\}$, $a \equiv b (\textrm{mod} n)$ ja $c \equiv d (\textrm{mod} n)$
# \begin{enumerate}
#     \item $a + c \equiv b + d (\textrm{mod} n)$
#     \item $ac \equiv bd (\textrm{mod} n)$
#     \item $a^k \equiv b^k (\textrm{mod} n)$
# \end{enumerate}
#
# \subsection{Verkot}
# Solmut ja kaaret, noder och bågar eller kantar
#
# Määritelmä: Suunnattu verkko $G$ on pari $(V, E)$, missä $V \neq \emptyset$ on solmujen joukko ja $E=\{(a,b) \in V \times V | \textrm{solmusta} a \to b \}$
#
# Määritelmä: $G = (V, E)$ on suunnattu verkko, riktad graf
#
# $(a, a) \in E$ silmukka, lähtöaste $\textrm{deg}^+(a)$ ja tuloaste $\textrm{deg}^-(a)$.
#
# Määritelmä: suuntaamaton verkko, $G$ on pari $(V, E)$
#
# $E = \{ (a, b) \in V \times V | a - b \}$
#
# Määritelmä: Vierekkäisiä $(a,a) \in E, \textrm{deg}(a)$
#
# Ei yhtään silmukkaa $\to$ yksinkertainen verkko
#
# Määritemä: yksinkertainen verkko $G = (V, E)$ on kaksijakoinen, jos solmujen joukko $V$ voidaan jakaa kahdeksi erilliseksi joukoksi $V_1$ ja $V_2$, $V_1 \cup V_2 = V$ viivat yhdistävät jokaiset solmut.
#
# Määritelmä: $G_1$ ja $G_2$ oavt isomorfiset:
# \begin{enumerate}
#     \item Bijektio $f: V_1 \to V_2$
#     \item $\forall a, b \in V_1$ pätee, että solmut $a$ ja $b$ ovat vierekkäisiä verkossa $G_1$, jos ja vain jos $f(a)$ ja $f(b)$ ovat vierekkäisiä verkossa $G_2$.
# \end{enumerate}
#
# Lause: yksinkertaisia verkkoja ja isomorfismi:
# \begin{enumerate}
#     \item Yhtä monta solmua ja viivaa
#     \item $\forall a \in V$, $\textrm{deg}(a) = \textrm{deg}(f(a))$
# \end{enumerate}
#
# Määritelmä: Polku solmusta $v_1 \to v_n$, pituus, sykli jos
# \begin{enumerate}
#     \item Pituus $\geq$ 2, cyklisk stig
#     \item $v_1 = v_n$
#     \item $V_2, \dots, v_{n-1}$ ei esiinny polussa useammin kuin kerran
# \end{enumerate}
#
# Yhtenäinen: kahden eri solmun välillä pn polku
